# %% [markdown]
# # Ice Cream Sales Analysis Notebook
#
# This notebook analyzes ice cream sales data to understand performance trends.
# It begins by loading the dataset and checking the basic structure.
# The workflow then looks for seasonal behavior, demand changes, and patterns.
# Later cells support charts and simple forecasting or comparison tasks.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
fr

# %%
df=pd.read_csv(r"C:\MCA\ai\Ice_cream selling data.csv")
df
# Out:
#     Temperature (°C)  Ice Cream Sales (units)
# 0          -4.662263                41.842986
# 1          -4.316559                34.661120
# 2          -4.213985                39.383001
# 3          -3.949661                37.539845
# 4          -3.578554                32.284531
# 5          -3.455712                30.001138
# 6          -3.108440                22.635401
# 7          -3.081303                25.365022
# 8          -2.672461                19.226970
# 9          -2.652287                20.279679
# 10         -2.651498                13.275828
# 11         -2.288264                18.123991
# 12         -2.111870                11.218294
# 13         -1.818938                10.012868
# 14         -1.660348                12.615181
# 15         -1.326379                10.957731
# 16         -1.173123                 6.689123
# 17         -0.773330                 9.392969
# 18         -0.673753                 5.210163
# ...

# %%
x=df['Temperature (°C)'].to

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model_linear = LinearRegression()
model_linear.fit(x_train, y_train)
y_pred = model_linear.predict(x_test)

# %%
model_poly = PolynomialRegression(degree=2)
poly = PolynomialFeatures(degree=2)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

# %%
model=
